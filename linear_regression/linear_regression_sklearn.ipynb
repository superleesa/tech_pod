# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Importing csv and Feature Selection

# %%
df_diabetes = pd.read_csv("diabetes_single_feature.csv")

# %%
df_diabetes.head(10)
# Out:
#     bmi  diabetes_progression
# 0  32.1                   151
# 1  21.6                    75
# 2  30.5                   141
# 3  25.3                   206
# 4  23.0                   135
# 5  22.6                    97
# 6  22.0                   138
# 7  26.2                    63
# 8  32.1                   110
# 9  30.0                   310

# %%
# select feature and lebal
y = df_diabetes["diabetes_progression"]
x = df_diabetes["bmi"].to_numpy().reshape(-1, 1)

# %% [markdown]
# ## Model Training and Prediction

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, random_state=0)

# %%
model = LinearRegression()
model.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
pred_y = model.predict(test_x)

# %% [markdown]
# ## Evaluation

# %%
# evaluation using MSE
print(mean_squared_error(test_y, pred_y, squared=False))
# Out:
# 59.75762152710471

# %%
plt.scatter(test_x, test_y)
plt.plot(test_x, pred_y, color="red")
plt.xlabel("BMI")
plt.ylabel("Diabetes Progression")
# Out:
# Text(0, 0.5, 'Diabetes Progression')

# %%
plt.plot([x for x in range(45, 351)], [x for x in range(45, 351)], color="black")
plt.scatter(test_y, pred_y)
plt.xlabel("true y")
plt.ylabel("predicted y")
# Out:
# Text(0, 0.5, 'predicted y')

# %%
model.coef_
# Out:
# array([10.42508389])

# %% [markdown]
# ## All Code

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt


df_diabetes = pd.read_csv("diabetes.csv")

y = df_diabetes["diabetes_progression"]
X = df_diabetes.iloc[:,df_diabetes.columns != "diabetes_progression"]

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state=0)

model = LinearRegression()
model.fit(train_X, train_y)

pred_y = model.predict(test_X)

# evaluation
print(mean_squared_error(test_y, pred_y, squared=False))

plt.plot([x for x in range(45, 351)], [x for x in range(45, 351)], color="black")
plt.scatter(test_y, pred_y)
plt.xlabel("true y")
plt.ylabel("predicted y")

# %% [markdown]
# ## Single Linear Regression (s5)

# %%
y = df_diabetes["diabetes_progression"]
X = df_diabetes["s5"].to_numpy().reshape(-1, 1)

train_X, test_X, train_y, test_y = train_test_split(X, y, random_state=0)

model = LinearRegression()
model.fit(train_X, train_y)

pred_y = model.predict(test_X)

# evaluation
print(mean_squared_error(test_y, pred_y, squared=False))

plt.plot([x for x in range(45, 351)], [x for x in range(45, 351)], color="black")
plt.scatter(test_y, pred_y)
plt.xlabel("true y")
plt.ylabel("predicted y")
# Out:
# 59.28009942227952
# Text(0, 0.5, 'predicted y')
